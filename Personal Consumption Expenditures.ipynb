# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile
import os

# Path to your zip file in Google Drive
zip_path = '/content/abc.zip'

# Extract the zip file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall('/content/tomat')

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
file_path = '/content/abc.zip'
df = pd.read_csv(file_path)

# Display the first few rows of the dataset
df.head()
# Out:
#   observation_date    PCE   PERCENTAGE
# 0       1959-01-01  306,1  1092855,00%
# 1       1959-02-01  309,6  1094580,00%
# 2       1959-03-01  312,7  1096135,00%
# 3       1959-04-01  312,2  1097660,00%
# 4       1959-05-01  316,1  1099355,00%

# %%
# Check for missing values
df.isnull().sum()
# Out:
# observation_date    0
# PCE                 0
# PERCENTAGE          0
# dtype: int64

# %%
# Convert columns to appropriate data types
df['observation_date'] = pd.to_datetime(df['observation_date'], errors='coerce')
df['PCE'] = pd.to_numeric(df['PCE'], errors='coerce')
df['PERCENTAGE'] = pd.to_numeric(df['PERCENTAGE'], errors='coerce')

# Drop rows with missing values after conversion
df.dropna(inplace=True)

# Verify data types
df.dtypes
# Out:
# observation_date    datetime64[ns]
# PCE                        float64
# PERCENTAGE                 float64
# dtype: object

# %%
# Summary statistics
df.describe()
# Out:
#       observation_date  PCE  PERCENTAGE
# count                0  0.0         0.0
# mean               NaT  NaN         NaN
# min                NaT  NaN         NaN
# 25%                NaT  NaN         NaN
# 50%                NaT  NaN         NaN
# 75%                NaT  NaN         NaN
# max                NaT  NaN         NaN
# std                NaN  NaN         NaN

# %%
# Correlation heatmap
numeric_df = df.select_dtypes(include=[np.number])
plt.figure(figsize=(8, 6))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
sns.pairplot(numeric_df)
plt.show()

# %%
# Plotting PCE over time
plt.figure(figsize=(12, 6))
plt.plot(df['observation_date'], df['PCE'], label='PCE')
plt.xlabel('Date')
plt.ylabel('PCE')
plt.title('Personal Consumption Expenditures Over Time')
plt.legend()
plt.show()
